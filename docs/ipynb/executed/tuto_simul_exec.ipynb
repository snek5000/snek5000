# %% [markdown]
# # Part 2: Executing the simulation

# %% [markdown]
# ## Initialize and setup up simulation parameters (recap)

# %% [markdown]
# In the previous tutorial we saw how to install the packages and setup a simulation run. Let us do it here in one step.

# %%
from phill.solver import Simul

params = Simul.create_default_params()
params.oper.nx = 12
params.oper.ny = 10
params.oper.nz = 8

params.oper.nproc_min = 2

params.nek.general.num_steps = 10
params.nek.general.time_stepper = "bdf2"
params.nek.general.write_interval = 10

params.nek.stat.av_step = 3
params.nek.stat.io_step = 10

sim = Simul(params)
# Out:
# [10/12/21 23:21:58] WARNING  Missing a configuration file describing compilers    ]8;id=726868;file:///home/avmo/src/snek5000/snek5000/src/snek5000/output/base.py\base.py]8;;\:145
#                              and flags. Create one at either of the following
#                              paths to avoid future warnings:
#                              /home/avmo/.config/snek5000/archmage.yml
#                              /home/avmo/src/snek5000/snek5000-phill/src/phill/etc
#                              /archmage.yml
#                     INFO     Using default configuration for now:                 ]8;id=589481;file:///home/avmo/src/snek5000/snek5000/src/snek5000/output/base.py\base.py]8;;\:154
#                              /home/avmo/src/snek5000/snek5000/src/snek5000/assets
#                              /default_configfile.yml
#                     WARNING  No module named 'paraview'                     ]8;id=991908;file:///home/avmo/src/snek5000/snek5000/src/snek5000/output/phys_fields.py\phys_fields.py]8;;\:12
#                     INFO     ******************************************           ]8;id=452024;file:///home/avmo/src/snek5000/snek5000/src/snek5000/output/base.py\base.py]8;;\:492
#                     INFO     solver: <class 'phill.output.OutputPhill'>           ]8;id=8034;file:///home/avmo/src/snek5000/snek5000/src/snek5000/output/base.py\base.py]8;;\:493
#                     INFO     path_run: /home/avmo/Sim_data/phill_run_12x10x8_V1.x ]8;id=929687;file:///home/avmo/src/snek5000/snek5000/src/snek5000/output/base.py\base.py]8;;\:494
#                              1.x1._2021-10-12_23-21-58
#                     INFO     ******************************************           ]8;id=705735;file:///home/avmo/src/snek5000/snek5000/src/snek5000/output/base.py\base.py]8;;\:495
# sim:                <class 'phill.solver.SimulPhill'>
#                     INFO     Searching for a log file...                   ]8;id=426932;file:///home/avmo/src/snek5000/snek5000/src/snek5000/output/print_stdout.py\print_stdout.py]8;;\:29
#                     INFO     Cannot find a .log to parse in /home/avmo/Sim ]8;id=776835;file:///home/avmo/src/snek5000/snek5000/src/snek5000/output/print_stdout.py\print_stdout.py]8;;\:42
#                              _data/phill_run_12x10x8_V1.x1.x1._2021-10-12_
#                              23-21-58.
# sim.output:         <class 'phill.output.OutputPhill'>
#                     INFO     Writing params files... /home/avmo/Sim_data/phill_ru ]8;id=211117;file:///home/avmo/src/snek5000/snek5000/src/snek5000/output/base.py\base.py]8;;\:509
#                              n_12x10x8_V1.x1.x1._2021-10-12_23-21-58/phill.par,
#                              params_simul.xml, info_solver.xml
#                     INFO     Copying with shutil.copytree ...                     ]8;id=27421;file:///home/avmo/src/snek5000/snek5000/src/snek5000/output/base.py\base.py]8;;\:354
#                     INFO     Copied:                                              ]8;id=745170;file:///home/avmo/src/snek5000/snek5000/src/snek5000/output/base.py\base.py]8;;\:394
#                              /home/avmo/src/snek5000/snek5000-phill/src/phill ->
#                              /home/avmo/Sim_data/phill_run_12x10x8_V1.x1.x1._2021
#                              -10-12_23-21-58
#                     INFO     Writing box file... /home/avmo/Sim_data/phill_run_12 ]8;id=138427;file:///home/avmo/src/snek5000/snek5000/src/snek5000/output/base.py\base.py]8;;\:400
#                              x10x8_V1.x1.x1._2021-10-12_23-21-58/phill.box
#                     INFO     Writing SIZE file... /home/avmo/Sim_data/phill_run_1 ]8;id=943452;file:///home/avmo/src/snek5000/snek5000/src/snek5000/output/base.py\base.py]8;;\:410
#                              2x10x8_V1.x1.x1._2021-10-12_23-21-58/SIZE

# %%
# !ls {sim.path_run}
# Out:
# build.log	 makefile_usr.inc  phill.log  SIZE	 toolbox
# etc		 params_simul.xml  phill.par  Snakefile
# info_solver.xml  phill.box	   phill.usr  templates

# %% [markdown]
# ## Execute the simulation
#
# To run the simulation we need to execute certain commands. These are described
# using [snakemake](https://snakemake.rtfd.io) in the Snakefile. Let's look at
# the rules defined in the Snakefile (which are nearly generic for any Nek5000
# case).

# %%
sim.make.list()
# Out:
# Changing to shadow directory: /home/avmo/Sim_data/phill_run_12x10x8_V1.x1.x1._2021-10-12_23-21-58
#                     WARNING  Missing a configuration file describing compilers    ]8;id=5845;file:///home/avmo/src/snek5000/snek5000/src/snek5000/output/base.py\base.py]8;;\:145
#                              and flags. Create one at either of the following
#                              paths to avoid future warnings:
#                              /home/avmo/.config/snek5000/archmage.yml
#                              /home/avmo/src/snek5000/snek5000-phill/src/phill/etc
#                              /archmage.yml
#                     INFO     Using default configuration for now:                 ]8;id=524966;file:///home/avmo/src/snek5000/snek5000/src/snek5000/output/base.py\base.py]8;;\:154
#                              /home/avmo/src/snek5000/snek5000/src/snek5000/assets
#                              /default_configfile.yml
#                     INFO     Using os.cpu_count() to detect maximum number of  ]8;id=682448;file:///home/avmo/src/snek5000/snek5000/src/snek5000/clusters.py\clusters.py]8;;\:23
#                              processors available
# all
# mesh
# show_config
# build_third_party
# compile
# mpiexec
# run
# run_fg
# clean
# cleansimul
# clean3rd
# cleanall
# archive
# internal_generate_box
# internal_move_box
# internal_generate_map
# internal_generate_makefile
# internal_generate_session
# True

# %% [markdown]
# The rules in the Snakefile are either shell commands or Python code which
# handle different parts of the build step, such as building a mesh (rule
# `mesh`), compiling (rule `compile`) and running the simulation (rule `run` or
# `run_fg`). The rules can be executed on by one by passing them as strings to
# the [exec](snek5000.make.Make.exec) method of the `sim.make` object. The
# default parameter is to do everything to run a simulation.
#
# From a user's perspective the following rules are essential:
# - `compile`: Only compile the executable
# - `run`: Run the simulation in the background (non-blocking)
# - `run_fg`: Run the simulation in the foreground (blocking, till the simulation is over / terminated)

# %% [markdown]
# ### Debug mode
#
# During development, it is useful to turn on the debug environment variable.

# %%
import os
os.environ["SNEK_DEBUG"] = "1"

# %% [markdown]
# The equivalent of this in the shell command line would be ``export
# SNEK_DEBUG=1``. By doing so, snek5000 would:
#
# - suppress the compiler warnings in the Nek5000 core source code. See {func}`snek5000.util.smake.append_debug_flags`
# - activate the code blocks under the preprocessing flag in Fortran sources `#ifdef DEBUG`

# %% [markdown]
# Now let's execute the simulation

# %%
sim.make.exec?
# Out:
# Signature: sim.make.exec(rules=('run',), dryrun=False, **kwargs)
# Docstring:
# Execute snakemake rules in sequence.
#
# :param iterable rules: Snakemake rules to be executed
# :param bool dryrun: Dry run snakemake without executing
#
# For more on available keyword arguments refer to `Snakemake API documentation`_.
#
# :returns: True if workflow execution was successful.
#
# .. _Snakemake API documentation: https://snakemake.readthedocs.io/en/stable/api_reference/snakemake.html
#
# Examples
# --------
#
# >>> sim.make.exec(['compile'])
# >>> sim.make.exec(['run'], resources={'nproc': 4})
#
# It is also possible to do the same directly from command line
# by changing to the simulation directory and executing::
#
#     snakemake -j compile
#     snakemake -j1 --resources nproc=2 run
#
# The flag ``-j`` is short for ``--jobs`` and sets the number of
# threads available for snakemake rules to execute.
#
# .. seealso:: Useful Snakemake `command line arguments`_
#
# .. _command line arguments: https://snakemake.readthedocs.io/en/stable/executing/cli.html#useful-command-line-arguments
# File:      ~/src/snek5000/snek5000/src/snek5000/make.py
# Type:      method

# %%
sim.make.exec(['run_fg'])
# Out:
# Changing to shadow directory: /home/avmo/Sim_data/phill_run_12x10x8_V1.x1.x1._2021-10-12_23-21-58
#                     WARNING  Missing a configuration file describing compilers    ]8;id=10702;file:///home/avmo/src/snek5000/snek5000/src/snek5000/output/base.py\base.py]8;;\:145
#                              and flags. Create one at either of the following
#                              paths to avoid future warnings:
#                              /home/avmo/.config/snek5000/archmage.yml
#                              /home/avmo/src/snek5000/snek5000-phill/src/phill/etc
#                              /archmage.yml
#                     INFO     Using default configuration for now:                 ]8;id=79232;file:///home/avmo/src/snek5000/snek5000/src/snek5000/output/base.py\base.py]8;;\:154
#                              /home/avmo/src/snek5000/snek5000/src/snek5000/assets
#                              /default_configfile.yml
#                     INFO     Using os.cpu_count() to detect maximum number of  ]8;id=734916;file:///home/avmo/src/snek5000/snek5000/src/snek5000/clusters.py\clusters.py]8;;\:23
#                              processors available
# Building DAG of jobs...
# Executing subworkflow Nek5000.
# Building DAG of jobs...
# Nothing to be done.
# Complete log: /home/avmo/src/snek5000/snek5000/lib/Nek5000/.snakemake/log/2021-10-12T232158.804271.snakemake.log
# Executing main workflow.
# Using shell: /usr/bin/bash
# Provided cores: 1 (use --cores to define parallelism)
# Rules claiming more threads will be scaled down.
# Job stats:
# job                           count    min threads    max threads
# --------------------------  -------  -------------  -------------
# compile                           1              1              1
# internal_generate_box             1              1              1
# internal_generate_makefile        1              1              1
# internal_generate_map             1              1              1
# internal_generate_session         1              1              1
# internal_move_box                 1              1              1
# run_fg                            1              1              1
# total                             7              1              1
#
# Select jobs to execute...
#
# [Tue Oct 12 23:21:58 2021]
# rule internal_generate_session:
#     output: SESSION.NAME
#     jobid: 4
#     resources: tmpdir=/tmp
#
# [Tue Oct 12 23:21:58 2021]
# Finished job 4.
# 1 of 7 steps (14%) done
# Select jobs to execute...
#
# [Tue Oct 12 23:21:58 2021]
# rule internal_generate_box:
#     input: phill.box, /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/bin/genbox
#     output: box.re2
#     jobid: 2
#     resources: tmpdir=/tmp
#
# [Tue Oct 12 23:21:58 2021]
# Finished job 2.
# 2 of 7 steps (29%) done
# Select jobs to execute...
#
# [Tue Oct 12 23:21:58 2021]
# rule internal_move_box:
#     input: box.re2
#     output: phill.re2
#     jobid: 1
#     resources: tmpdir=/tmp
#  input file name:
# -3                                         spatial dimension (dim<0 will create box.re2)
# 2                                          number of fields
#  T T F           2   2.0000000000000000
#            1  i1#
#            1  i1#
#            1  i1#
#            1  i1#
#            1  i1#
#            1  i1#
#            1  i1#
#            1  i1#
#            1  i1#
#            1  i1#
#            1  i1#
#            1  i1#
#            1  i1#
#            1  i1#
#            1  i1#
#            1  i1#
# Box
# -12 -10 -8                                nelx nely nelz
# Reading         960 =       12       10        8 elements for box   1.
# Reading           2 =
# 0.0000 1.0000 1.0000                      x0 x1 ratio
# 0.0000 1.0000 1.0000                      y0 y1 ratio
# 0.0000 1.0000 1.0000                      z0 z1 ratio
# P  ,P  ,W  ,W  ,P  ,P                     Velocity BCs
#  Beginning construction of box.re2
#          960  elements will be created for            1  boxes.
# [Tue Oct 12 23:21:58 2021]
# Finished job 1.
# 3 of 7 steps (43%) done
# Select jobs to execute...
#
# [Tue Oct 12 23:21:58 2021]
# rule internal_generate_map:
#     input: phill.re2, /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/bin/genmap
#     output: phill.ma2
#     jobid: 3
#     resources: tmpdir=/tmp
#
# [Tue Oct 12 23:21:58 2021]
# Finished job 3.
# 4 of 7 steps (57%) done
# Select jobs to execute...
#
# [Tue Oct 12 23:21:59 2021]
# rule internal_generate_makefile:
#     input: phill.re2, phill.ma2, phill.usr, /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/bin/nekconfig
#     output: makefile, .state
#     jobid: 6
#     resources: tmpdir=/tmp
#
# [Tue Oct 12 23:21:59 2021]
# Finished job 6.
# 5 of 7 steps (71%) done
# Select jobs to execute...
#
# [Tue Oct 12 23:21:59 2021]
# rule compile:
#     input: SIZE, phill.usr, makefile_usr.inc, makefile, /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/3rd_party/gslib/lib/libgs.a, /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/3rd_party/blasLapack/libblasLapack.a
#     output: nek5000
#     jobid: 5
#     resources: tmpdir=/tmp
# Input .rea / .re2 name:
#  reading phill.re2
# Input mesh tolerance (default 0.2):
# NOTE: smaller is better, but generous is more forgiving for bad meshes.
#  reading mesh data ...
#  start locglob_lexico:           8         960        7680   1.0000000000000000E-002
#  locglob:           1           1        7680
#  locglob:           2          13        7680
#  locglob:           3         143        7680
#  locglob:           1        1287        7680
#  locglob:           2        1287        7680
#  locglob:           3        1287        7680
#  locglob:           1        1287        7680
#  locglob:           2        1287        7680
#  locglob:           3        1287        7680
#  done locglob_lexico:        1287        1287        7680           8
#  start periodic vtx:         960        1287
#            1 1  5  3  0.00000000E+00        1 shift
#            1 5  5  3  0.00000000E+00        2 shift
#            2 5  5  3  2.77555756E-17        3 shift
#            3 5  5  3  0.00000000E+00        4 shift
#            4 5  5  3  0.00000000E+00        5 shift
#            5 5  5  3  1.11022302E-16        6 shift
#            6 5  5  3  1.11022302E-16        7 shift
#            7 5  5  3  2.22044605E-16        8 shift
#            8 5  5  3  2.22044605E-16        9 shift
#            9 5  5  3  0.00000000E+00       10 shift
#           10 5  5  3  0.00000000E+00       11 shift
#           11 5  5  3  2.22044605E-16       12 shift
#           12 2  5  3  0.00000000E+00       13 shift
#           12 5  5  3  2.22044605E-16       14 shift
#           13 1  5  3  5.55111512E-17       15 shift
#           13 5  5  3  5.55111512E-17       16 shift
#           14 5  5  3  6.20633538E-17       17 shift
#           15 5  5  3  5.55111512E-17       18 shift
#           16 5  5  3  5.55111512E-17       19 shift
#           17 5  5  3  1.24126708E-16       20 shift
#           18 5  5  3  1.24126708E-16       21 shift
#           19 5  5  3  2.28878340E-16       22 shift
#           20 5  5  3  2.28878340E-16       23 shift
#           21 5  5  3  5.55111512E-17       24 shift
#           22 5  5  3  5.55111512E-17       25 shift
#           23 5  5  3  2.28878340E-16       26 shift
#           24 2  5  3  5.55111512E-17       27 shift
#           24 5  5  3  2.28878340E-16       28 shift
#           25 1  5  3  1.11022302E-16       29 shift
#           25 5  5  3  1.11022302E-16       30 shift
#           26 5  5  3  1.14439170E-16       31 shift
#           27 5  5  3  1.11022302E-16       32 shift
#           28 5  5  3  1.11022302E-16       33 shift
#           29 5  5  3  1.57009246E-16       34 shift
#           30 5  5  3  1.57009246E-16       35 shift
#           31 5  5  3  2.48253415E-16       36 shift
#           32 5  5  3  2.48253415E-16       37 shift
#           33 5  5  3  1.11022302E-16       38 shift
#           34 5  5  3  1.11022302E-16       39 shift
#           35 5  5  3  2.48253415E-16       40 shift
#           36 2  5  3  1.11022302E-16       41 shift
#           36 5  5  3  2.48253415E-16       42 shift
#           37 1  5  3  1.11022302E-16       43 shift
#           37 5  5  3  1.11022302E-16       44 shift
#           38 5  5  3  1.14439170E-16       45 shift
#           39 5  5  3  1.11022302E-16       46 shift
#           40 5  5  3  1.11022302E-16       47 shift
#           41 5  5  3  1.57009246E-16       48 shift
#           42 5  5  3  1.57009246E-16       49 shift
#           43 5  5  3  2.48253415E-16       50 shift
#           44 5  5  3  2.48253415E-16       51 shift
#           45 5  5  3  1.11022302E-16       52 shift
#           46 5  5  3  1.11022302E-16       53 shift
#           47 5  5  3  2.48253415E-16       54 shift
#           48 2  5  3  1.11022302E-16       55 shift
#           48 5  5  3  2.48253415E-16       56 shift
#           49 1  5  3  1.11022302E-16       57 shift
#           49 5  5  3  1.11022302E-16       58 shift
#           50 5  5  3  1.14439170E-16       59 shift
#           51 5  5  3  1.11022302E-16       60 shift
#           52 5  5  3  1.11022302E-16       61 shift
#           53 5  5  3  1.57009246E-16       62 shift
#           54 5  5  3  1.57009246E-16       63 shift
#           55 5  5  3  2.48253415E-16       64 shift
#           56 5  5  3  2.48253415E-16       65 shift
#           57 5  5  3  1.11022302E-16       66 shift
#           58 5  5  3  1.11022302E-16       67 shift
#           59 5  5  3  2.48253415E-16       68 shift
#           60 2  5  3  1.11022302E-16       69 shift
#           60 5  5  3  2.48253415E-16       70 shift
#           61 1  5  3  0.00000000E+00       71 shift
#           61 5  5  3  0.00000000E+00       72 shift
#           62 5  5  3  2.77555756E-17       73 shift
#           63 5  5  3  0.00000000E+00       74 shift
#           64 5  5  3  0.00000000E+00       75 shift
#           65 5  5  3  1.11022302E-16       76 shift
#           66 5  5  3  1.11022302E-16       77 shift
#           67 5  5  3  2.22044605E-16       78 shift
#           68 5  5  3  2.22044605E-16       79 shift
#           69 5  5  3  0.00000000E+00       80 shift
#           70 5  5  3  0.00000000E+00       81 shift
#           71 5  5  3  2.22044605E-16       82 shift
#           72 2  5  3  0.00000000E+00       83 shift
#           72 5  5  3  2.22044605E-16       84 shift
#           73 1  5  3  0.00000000E+00       85 shift
#           73 5  5  3  0.00000000E+00       86 shift
#           74 5  5  3  2.77555756E-17       87 shift
#           75 5  5  3  0.00000000E+00       88 shift
#           76 5  5  3  0.00000000E+00       89 shift
#           77 5  5  3  1.11022302E-16       90 shift
#           78 5  5  3  1.11022302E-16       91 shift
#           79 5  5  3  2.22044605E-16       92 shift
#           80 5  5  3  2.22044605E-16       93 shift
#           81 5  5  3  0.00000000E+00       94 shift
#           82 5  5  3  0.00000000E+00       95 shift
#           83 5  5  3  2.22044605E-16       96 shift
#           84 2  5  3  0.00000000E+00       97 shift
#           84 5  5  3  2.22044605E-16       98 shift
#           85 1  5  3  0.00000000E+00       99 shift
#           85 5  5  3  0.00000000E+00      100 shift
#           86 5  5  3  2.77555756E-17      101 shift
#           87 5  5  3  0.00000000E+00      102 shift
#           88 5  5  3  0.00000000E+00      103 shift
#           89 5  5  3  1.11022302E-16      104 shift
#           90 5  5  3  1.11022302E-16      105 shift
#           91 5  5  3  2.22044605E-16      106 shift
#           92 5  5  3  2.22044605E-16      107 shift
#           93 5  5  3  0.00000000E+00      108 shift
#           94 5  5  3  0.00000000E+00      109 shift
#           95 5  5  3  2.22044605E-16      110 shift
#           96 2  5  3  0.00000000E+00      111 shift
#           96 5  5  3  2.22044605E-16      112 shift
#           97 1  5  3  2.22044605E-16      113 shift
#           97 5  5  3  2.22044605E-16      114 shift
#           98 5  5  3  2.23772605E-16      115 shift
#           99 5  5  3  2.22044605E-16      116 shift
#          100 5  5  3  2.22044605E-16      117 shift
#          101 5  5  3  2.48253415E-16      118 shift
#          102 5  5  3  2.48253415E-16      119 shift
#          103 5  5  3  3.14018492E-16      120 shift
#          104 5  5  3  3.14018492E-16      121 shift
#          105 5  5  3  2.22044605E-16      122 shift
#          106 5  5  3  2.22044605E-16      123 shift
#          107 5  5  3  3.14018492E-16      124 shift
#          108 2  5  3  2.22044605E-16      125 shift
#          108 5  5  3  3.14018492E-16      126 shift
#          109 1  5  3  2.22044605E-16      127 shift
#          109 5  5  3  2.22044605E-16      128 shift
#          110 5  5  3  2.23772605E-16      129 shift
#          111 5  5  3  2.22044605E-16      130 shift
#          112 5  5  3  2.22044605E-16      131 shift
#          113 5  5  3  2.48253415E-16      132 shift
#          114 5  5  3  2.48253415E-16      133 shift
#          115 5  5  3  3.14018492E-16      134 shift
#          116 5  5  3  3.14018492E-16      135 shift
#          117 5  5  3  2.22044605E-16      136 shift
#          118 5  5  3  2.22044605E-16      137 shift
#          119 5  5  3  3.14018492E-16      138 shift
#          120 2  5  3  2.22044605E-16      139 shift
#          120 5  5  3  3.14018492E-16      140 shift
#          121 1  5  3  0.00000000E+00      141 shift
#          132 2  5  3  0.00000000E+00      142 shift
#          133 1  5  3  5.55111512E-17      143 shift
#          144 2  5  3  5.55111512E-17      144 shift
#          145 1  5  3  1.11022302E-16      145 shift
#          156 2  5  3  1.11022302E-16      146 shift
#          157 1  5  3  1.11022302E-16      147 shift
#          168 2  5  3  1.11022302E-16      148 shift
#          169 1  5  3  1.11022302E-16      149 shift
#          180 2  5  3  1.11022302E-16      150 shift
#          181 1  5  3  0.00000000E+00      151 shift
#          192 2  5  3  0.00000000E+00      152 shift
#          193 1  5  3  0.00000000E+00      153 shift
#          204 2  5  3  0.00000000E+00      154 shift
#          205 1  5  3  0.00000000E+00      155 shift
#          216 2  5  3  0.00000000E+00      156 shift
#          217 1  5  3  2.22044605E-16      157 shift
#          228 2  5  3  2.22044605E-16      158 shift
#          229 1  5  3  2.22044605E-16      159 shift
#          240 2  5  3  2.22044605E-16      160 shift
#          241 1  5  3  0.00000000E+00      161 shift
#          252 2  5  3  0.00000000E+00      162 shift
#          253 1  5  3  5.55111512E-17      163 shift
#          264 2  5  3  5.55111512E-17      164 shift
#          265 1  5  3  1.11022302E-16      165 shift
#          276 2  5  3  1.11022302E-16      166 shift
#          277 1  5  3  1.11022302E-16      167 shift
#          288 2  5  3  1.11022302E-16      168 shift
#          289 1  5  3  1.11022302E-16      169 shift
#          300 2  5  3  1.11022302E-16      170 shift
#          301 1  5  3  0.00000000E+00      171 shift
#          312 2  5  3  0.00000000E+00      172 shift
#          313 1  5  3  0.00000000E+00      173 shift
#          324 2  5  3  0.00000000E+00      174 shift
#          325 1  5  3  0.00000000E+00      175 shift
#          336 2  5  3  0.00000000E+00      176 shift
#          337 1  5  3  2.22044605E-16      177 shift
#          348 2  5  3  2.22044605E-16      178 shift
#          349 1  5  3  2.22044605E-16      179 shift
#          360 2  5  3  2.22044605E-16      180 shift
#          361 1  5  3  0.00000000E+00      181 shift
#          372 2  5  3  0.00000000E+00      182 shift
#          373 1  5  3  5.55111512E-17      183 shift
#          384 2  5  3  5.55111512E-17      184 shift
#          385 1  5  3  1.11022302E-16      185 shift
#          396 2  5  3  1.11022302E-16      186 shift
#          397 1  5  3  1.11022302E-16      187 shift
#          408 2  5  3  1.11022302E-16      188 shift
#          409 1  5  3  1.11022302E-16      189 shift
#          420 2  5  3  1.11022302E-16      190 shift
#          421 1  5  3  0.00000000E+00      191 shift
#          432 2  5  3  0.00000000E+00      192 shift
#          433 1  5  3  0.00000000E+00      193 shift
#          444 2  5  3  0.00000000E+00      194 shift
#          445 1  5  3  0.00000000E+00      195 shift
#          456 2  5  3  0.00000000E+00      196 shift
#          457 1  5  3  2.22044605E-16      197 shift
#          468 2  5  3  2.22044605E-16      198 shift
#          469 1  5  3  2.22044605E-16      199 shift
#          480 2  5  3  2.22044605E-16      200 shift
#          481 1  5  3  0.00000000E+00      201 shift
#          492 2  5  3  0.00000000E+00      202 shift
#          493 1  5  3  5.55111512E-17      203 shift
#          504 2  5  3  5.55111512E-17      204 shift
#          505 1  5  3  1.11022302E-16      205 shift
#          516 2  5  3  1.11022302E-16      206 shift
#          517 1  5  3  1.11022302E-16      207 shift
#          528 2  5  3  1.11022302E-16      208 shift
#          529 1  5  3  1.11022302E-16      209 shift
#          540 2  5  3  1.11022302E-16      210 shift
#          541 1  5  3  0.00000000E+00      211 shift
#          552 2  5  3  0.00000000E+00      212 shift
#          553 1  5  3  0.00000000E+00      213 shift
#          564 2  5  3  0.00000000E+00      214 shift
#          565 1  5  3  0.00000000E+00      215 shift
#          576 2  5  3  0.00000000E+00      216 shift
#          577 1  5  3  2.22044605E-16      217 shift
#          588 2  5  3  2.22044605E-16      218 shift
#          589 1  5  3  2.22044605E-16      219 shift
#          600 2  5  3  2.22044605E-16      220 shift
#          601 1  5  3  0.00000000E+00      221 shift
#          612 2  5  3  0.00000000E+00      222 shift
#          613 1  5  3  5.55111512E-17      223 shift
#          624 2  5  3  5.55111512E-17      224 shift
#          625 1  5  3  1.11022302E-16      225 shift
#          636 2  5  3  1.11022302E-16      226 shift
#          637 1  5  3  1.11022302E-16      227 shift
#          648 2  5  3  1.11022302E-16      228 shift
#          649 1  5  3  1.11022302E-16      229 shift
#          660 2  5  3  1.11022302E-16      230 shift
#          661 1  5  3  0.00000000E+00      231 shift
#          672 2  5  3  0.00000000E+00      232 shift
#          673 1  5  3  0.00000000E+00      233 shift
#          684 2  5  3  0.00000000E+00      234 shift
#          685 1  5  3  0.00000000E+00      235 shift
#          696 2  5  3  0.00000000E+00      236 shift
#          697 1  5  3  2.22044605E-16      237 shift
#          708 2  5  3  2.22044605E-16      238 shift
#          709 1  5  3  2.22044605E-16      239 shift
#          720 2  5  3  2.22044605E-16      240 shift
#          721 1  5  3  0.00000000E+00      241 shift
#          732 2  5  3  0.00000000E+00      242 shift
#          733 1  5  3  5.55111512E-17      243 shift
#          744 2  5  3  5.55111512E-17      244 shift
#          745 1  5  3  1.11022302E-16      245 shift
#          756 2  5  3  1.11022302E-16      246 shift
#          757 1  5  3  1.11022302E-16      247 shift
#          768 2  5  3  1.11022302E-16      248 shift
#          769 1  5  3  1.11022302E-16      249 shift
#          780 2  5  3  1.11022302E-16      250 shift
#          781 1  5  3  0.00000000E+00      251 shift
#          792 2  5  3  0.00000000E+00      252 shift
#          793 1  5  3  0.00000000E+00      253 shift
#          804 2  5  3  0.00000000E+00      254 shift
#          805 1  5  3  0.00000000E+00      255 shift
#          816 2  5  3  0.00000000E+00      256 shift
#          817 1  5  3  2.22044605E-16      257 shift
#          828 2  5  3  2.22044605E-16      258 shift
#          829 1  5  3  2.22044605E-16      259 shift
#          840 2  5  3  2.22044605E-16      260 shift
#          841 1  5  3  0.00000000E+00      261 shift
#          841 6  5  3  0.00000000E+00      262 shift
#          842 6  5  3  2.77555756E-17      263 shift
#          843 6  5  3  0.00000000E+00      264 shift
#          844 6  5  3  0.00000000E+00      265 shift
#          845 6  5  3  1.11022302E-16      266 shift
#          846 6  5  3  1.11022302E-16      267 shift
#          847 6  5  3  2.22044605E-16      268 shift
#          848 6  5  3  2.22044605E-16      269 shift
#          849 6  5  3  0.00000000E+00      270 shift
#          850 6  5  3  0.00000000E+00      271 shift
#          851 6  5  3  2.22044605E-16      272 shift
#          852 2  5  3  0.00000000E+00      273 shift
#          852 6  5  3  2.22044605E-16      274 shift
#          853 1  5  3  5.55111512E-17      275 shift
#          853 6  5  3  5.55111512E-17      276 shift
#          854 6  5  3  6.20633538E-17      277 shift
#          855 6  5  3  5.55111512E-17      278 shift
#          856 6  5  3  5.55111512E-17      279 shift
#          857 6  5  3  1.24126708E-16      280 shift
#          858 6  5  3  1.24126708E-16      281 shift
#          859 6  5  3  2.28878340E-16      282 shift
#          860 6  5  3  2.28878340E-16      283 shift
#          861 6  5  3  5.55111512E-17      284 shift
#          862 6  5  3  5.55111512E-17      285 shift
#          863 6  5  3  2.28878340E-16      286 shift
#          864 2  5  3  5.55111512E-17      287 shift
#          864 6  5  3  2.28878340E-16      288 shift
#          865 1  5  3  1.11022302E-16      289 shift
#          865 6  5  3  1.11022302E-16      290 shift
#          866 6  5  3  1.14439170E-16      291 shift
#          867 6  5  3  1.11022302E-16      292 shift
#          868 6  5  3  1.11022302E-16      293 shift
#          869 6  5  3  1.57009246E-16      294 shift
#          870 6  5  3  1.57009246E-16      295 shift
#          871 6  5  3  2.48253415E-16      296 shift
#          872 6  5  3  2.48253415E-16      297 shift
#          873 6  5  3  1.11022302E-16      298 shift
#          874 6  5  3  1.11022302E-16      299 shift
#          875 6  5  3  2.48253415E-16      300 shift
#          876 2  5  3  1.11022302E-16      301 shift
#          876 6  5  3  2.48253415E-16      302 shift
#          877 1  5  3  1.11022302E-16      303 shift
#          877 6  5  3  1.11022302E-16      304 shift
#          878 6  5  3  1.14439170E-16      305 shift
#          879 6  5  3  1.11022302E-16      306 shift
#          880 6  5  3  1.11022302E-16      307 shift
#          881 6  5  3  1.57009246E-16      308 shift
#          882 6  5  3  1.57009246E-16      309 shift
#          883 6  5  3  2.48253415E-16      310 shift
#          884 6  5  3  2.48253415E-16      311 shift
#          885 6  5  3  1.11022302E-16      312 shift
#          886 6  5  3  1.11022302E-16      313 shift
#          887 6  5  3  2.48253415E-16      314 shift
#          888 2  5  3  1.11022302E-16      315 shift
#          888 6  5  3  2.48253415E-16      316 shift
#          889 1  5  3  1.11022302E-16      317 shift
#          889 6  5  3  1.11022302E-16      318 shift
#          890 6  5  3  1.14439170E-16      319 shift
#          891 6  5  3  1.11022302E-16      320 shift
#          892 6  5  3  1.11022302E-16      321 shift
#          893 6  5  3  1.57009246E-16      322 shift
#          894 6  5  3  1.57009246E-16      323 shift
#          895 6  5  3  2.48253415E-16      324 shift
#          896 6  5  3  2.48253415E-16      325 shift
#          897 6  5  3  1.11022302E-16      326 shift
#          898 6  5  3  1.11022302E-16      327 shift
#          899 6  5  3  2.48253415E-16      328 shift
#          900 2  5  3  1.11022302E-16      329 shift
#          900 6  5  3  2.48253415E-16      330 shift
#          901 1  5  3  0.00000000E+00      331 shift
#          901 6  5  3  0.00000000E+00      332 shift
#          902 6  5  3  2.77555756E-17      333 shift
#          903 6  5  3  0.00000000E+00      334 shift
#          904 6  5  3  0.00000000E+00      335 shift
#          905 6  5  3  1.11022302E-16      336 shift
#          906 6  5  3  1.11022302E-16      337 shift
#          907 6  5  3  2.22044605E-16      338 shift
#          908 6  5  3  2.22044605E-16      339 shift
#          909 6  5  3  0.00000000E+00      340 shift
#          910 6  5  3  0.00000000E+00      341 shift
#          911 6  5  3  2.22044605E-16      342 shift
#          912 2  5  3  0.00000000E+00      343 shift
#          912 6  5  3  2.22044605E-16      344 shift
#          913 1  5  3  0.00000000E+00      345 shift
#          913 6  5  3  0.00000000E+00      346 shift
#          914 6  5  3  2.77555756E-17      347 shift
#          915 6  5  3  0.00000000E+00      348 shift
#          916 6  5  3  0.00000000E+00      349 shift
#          917 6  5  3  1.11022302E-16      350 shift
#          918 6  5  3  1.11022302E-16      351 shift
#          919 6  5  3  2.22044605E-16      352 shift
#          920 6  5  3  2.22044605E-16      353 shift
#          921 6  5  3  0.00000000E+00      354 shift
#          922 6  5  3  0.00000000E+00      355 shift
#          923 6  5  3  2.22044605E-16      356 shift
#          924 2  5  3  0.00000000E+00      357 shift
#          924 6  5  3  2.22044605E-16      358 shift
#          925 1  5  3  0.00000000E+00      359 shift
#          925 6  5  3  0.00000000E+00      360 shift
#          926 6  5  3  2.77555756E-17      361 shift
#          927 6  5  3  0.00000000E+00      362 shift
#          928 6  5  3  0.00000000E+00      363 shift
#          929 6  5  3  1.11022302E-16      364 shift
#          930 6  5  3  1.11022302E-16      365 shift
#          931 6  5  3  2.22044605E-16      366 shift
#          932 6  5  3  2.22044605E-16      367 shift
#          933 6  5  3  0.00000000E+00      368 shift
#          934 6  5  3  0.00000000E+00      369 shift
#          935 6  5  3  2.22044605E-16      370 shift
#          936 2  5  3  0.00000000E+00      371 shift
#          936 6  5  3  2.22044605E-16      372 shift
#          937 1  5  3  2.22044605E-16      373 shift
#          937 6  5  3  2.22044605E-16      374 shift
#          938 6  5  3  2.23772605E-16      375 shift
#          939 6  5  3  2.22044605E-16      376 shift
#          940 6  5  3  2.22044605E-16      377 shift
#          941 6  5  3  2.48253415E-16      378 shift
#          942 6  5  3  2.48253415E-16      379 shift
#          943 6  5  3  3.14018492E-16      380 shift
#          944 6  5  3  3.14018492E-16      381 shift
#          945 6  5  3  2.22044605E-16      382 shift
#          946 6  5  3  2.22044605E-16      383 shift
#          947 6  5  3  3.14018492E-16      384 shift
#          948 2  5  3  2.22044605E-16      385 shift
#          948 6  5  3  3.14018492E-16      386 shift
#          949 1  5  3  2.22044605E-16      387 shift
#          949 6  5  3  2.22044605E-16      388 shift
#          950 6  5  3  2.23772605E-16      389 shift
#          951 6  5  3  2.22044605E-16      390 shift
#          952 6  5  3  2.22044605E-16      391 shift
#          953 6  5  3  2.48253415E-16      392 shift
#          954 6  5  3  2.48253415E-16      393 shift
#          955 6  5  3  3.14018492E-16      394 shift
#          956 6  5  3  3.14018492E-16      395 shift
#          957 6  5  3  2.22044605E-16      396 shift
#          958 6  5  3  2.22044605E-16      397 shift
#          959 6  5  3  3.14018492E-16      398 shift
#          960 2  5  3  2.22044605E-16      399 shift
#          960 6  5  3  3.14018492E-16      400 shift
#  done periodic vtx
#  start rec_bisect:         960
#  done:    0.1%
#  done:    0.9%
#  done:    1.9%
#  done:    2.8%
#  done:    3.8%
#  done:    4.7%
#  done:    5.6%
#  done:    6.6%
#  done:    7.5%
#  done:    8.4%
#  done:    9.4%
#  done:   10.3%
#  done:   11.2%
#  done:   12.2%
#  done:   13.1%
#  done:   14.1%
#  done:   15.0%
#  done:   15.9%
#  done:   16.9%
#  done:   17.8%
#  done:   18.8%
#  done:   19.7%
#  done:   20.6%
#  done:   21.6%
#  done:   22.5%
#  done:   23.4%
#  done:   24.4%
#  done:   25.3%
#  done:   26.2%
#  done:   27.2%
#  done:   28.1%
#  done:   29.1%
#  done:   30.0%
#  done:   30.9%
#  done:   31.9%
#  done:   32.8%
#  done:   33.8%
#  done:   34.7%
#  done:   35.6%
#  done:   36.6%
#  done:   37.5%
#  done:   38.4%
#  done:   39.4%
#  done:   40.3%
#  done:   41.2%
#  done:   42.2%
#  done:   43.1%
#  done:   44.1%
#  done:   45.0%
#  done:   45.9%
#  done:   46.9%
#  done:   47.8%
#  done:   48.8%
#  done:   49.7%
#  done:   50.6%
#  done:   51.6%
#  done:   52.5%
#  done:   53.4%
#  done:   54.4%
#  done:   55.3%
#  done:   56.2%
#  done:   57.2%
#  done:   58.1%
#  done:   59.1%
#  done:   60.0%
#  done:   60.9%
#  done:   61.9%
#  done:   62.8%
#  done:   63.8%
#  done:   64.7%
#  done:   65.6%
#  done:   66.6%
#  done:   67.5%
#  done:   68.4%
#  done:   69.4%
#  done:   70.3%
#  done:   71.2%
#  done:   72.2%
#  done:   73.1%
#  done:   74.1%
#  done:   75.0%
#  done:   75.9%
#  done:   76.9%
#  done:   77.8%
#  done:   78.8%
#  done:   79.7%
#  done:   80.6%
#  done:   81.6%
#  done:   82.5%
#  done:   83.4%
#  done:   84.4%
#  done:   85.3%
#  done:   86.2%
#  done:   87.2%
#  done:   88.1%
#  done:   89.1%
#  done:   90.0%
#  done:   90.9%
#  done:   91.9%
#  done:   92.8%
#  done:   93.8%
#  done:   94.7%
#  done:   95.6%
#  done:   96.6%
#  done:   97.5%
#  done:   98.4%
#  done:   99.4%
#
#  done rec_bisect
# writing phill.ma2
# generating makefile ... done
# mpif77 -c  -O2 -cpp -fdefault-real-8 -fdefault-double-8 -std=legacy -march=native -mcmodel=medium -std=legacy -O0 -g -ffpe-trap=invalid,zero,overflow -DDEBUG -w -Itoolbox -DMPI -DUNDERSCORE -DGLOBAL_LONG_LONG -DTIMER -I/home/avmo/Sim_data/phill_run_12x10x8_V1.x1.x1._2021-10-12_23-21-58 -I/home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core -I./ -I /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/experimental /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/drive1.f -o obj/drive1.o
# mpif77 -c  -O2 -cpp -fdefault-real-8 -fdefault-double-8 -std=legacy -march=native -mcmodel=medium -std=legacy -O0 -g -ffpe-trap=invalid,zero,overflow -DDEBUG -w -Itoolbox -DMPI -DUNDERSCORE -DGLOBAL_LONG_LONG -DTIMER -I/home/avmo/Sim_data/phill_run_12x10x8_V1.x1.x1._2021-10-12_23-21-58 -I/home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core -I./ -I /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/experimental /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/drive2.f -o obj/drive2.o
# mpif77 -c  -O2 -cpp -fdefault-real-8 -fdefault-double-8 -std=legacy -march=native -mcmodel=medium -std=legacy -O0 -g -ffpe-trap=invalid,zero,overflow -DDEBUG -w -Itoolbox -DMPI -DUNDERSCORE -DGLOBAL_LONG_LONG -DTIMER -I/home/avmo/Sim_data/phill_run_12x10x8_V1.x1.x1._2021-10-12_23-21-58 -I/home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core -I./ -I /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/experimental /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/plan5.f -o obj/plan5.o
# mpif77 -c  -O2 -cpp -fdefault-real-8 -fdefault-double-8 -std=legacy -march=native -mcmodel=medium -std=legacy -O0 -g -ffpe-trap=invalid,zero,overflow -DDEBUG -w -Itoolbox -DMPI -DUNDERSCORE -DGLOBAL_LONG_LONG -DTIMER -I/home/avmo/Sim_data/phill_run_12x10x8_V1.x1.x1._2021-10-12_23-21-58 -I/home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core -I./ -I /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/experimental /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/plan4.f -o obj/plan4.o
# mpif77 -c  -O2 -cpp -fdefault-real-8 -fdefault-double-8 -std=legacy -march=native -mcmodel=medium -std=legacy -O0 -g -ffpe-trap=invalid,zero,overflow -DDEBUG -w -Itoolbox -DMPI -DUNDERSCORE -DGLOBAL_LONG_LONG -DTIMER -I/home/avmo/Sim_data/phill_run_12x10x8_V1.x1.x1._2021-10-12_23-21-58 -I/home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core -I./ -I /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/experimental /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/bdry.f -o obj/bdry.o
# mpif77 -c  -O2 -cpp -fdefault-real-8 -fdefault-double-8 -std=legacy -march=native -mcmodel=medium -std=legacy -O0 -g -ffpe-trap=invalid,zero,overflow -DDEBUG -w -Itoolbox -DMPI -DUNDERSCORE -DGLOBAL_LONG_LONG -DTIMER -I/home/avmo/Sim_data/phill_run_12x10x8_V1.x1.x1._2021-10-12_23-21-58 -I/home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core -I./ -I /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/experimental /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/coef.f -o obj/coef.o
# mpif77 -c  -O2 -cpp -fdefault-real-8 -fdefault-double-8 -std=legacy -march=native -mcmodel=medium -std=legacy -O0 -g -ffpe-trap=invalid,zero,overflow -DDEBUG -w -Itoolbox -DMPI -DUNDERSCORE -DGLOBAL_LONG_LONG -DTIMER -I/home/avmo/Sim_data/phill_run_12x10x8_V1.x1.x1._2021-10-12_23-21-58 -I/home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core -I./ -I /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/experimental /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/conduct.f -o obj/conduct.o
# mpif77 -c  -O2 -cpp -fdefault-real-8 -fdefault-double-8 -std=legacy -march=native -mcmodel=medium -std=legacy -O0 -g -ffpe-trap=invalid,zero,overflow -DDEBUG -w -Itoolbox -DMPI -DUNDERSCORE -DGLOBAL_LONG_LONG -DTIMER -I/home/avmo/Sim_data/phill_run_12x10x8_V1.x1.x1._2021-10-12_23-21-58 -I/home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core -I./ -I /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/experimental /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/connect1.f -o obj/connect1.o
# mpif77 -c  -O2 -cpp -fdefault-real-8 -fdefault-double-8 -std=legacy -march=native -mcmodel=medium -std=legacy -O0 -g -ffpe-trap=invalid,zero,overflow -DDEBUG -w -Itoolbox -DMPI -DUNDERSCORE -DGLOBAL_LONG_LONG -DTIMER -I/home/avmo/Sim_data/phill_run_12x10x8_V1.x1.x1._2021-10-12_23-21-58 -I/home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core -I./ -I /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/experimental /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/connect2.f -o obj/connect2.o
# mpif77 -c  -O2 -cpp -fdefault-real-8 -fdefault-double-8 -std=legacy -march=native -mcmodel=medium -std=legacy -O0 -g -ffpe-trap=invalid,zero,overflow -DDEBUG -w -Itoolbox -DMPI -DUNDERSCORE -DGLOBAL_LONG_LONG -DTIMER -I/home/avmo/Sim_data/phill_run_12x10x8_V1.x1.x1._2021-10-12_23-21-58 -I/home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core -I./ -I /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/experimental /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/dssum.f -o obj/dssum.o
# mpif77 -c  -O2 -cpp -fdefault-real-8 -fdefault-double-8 -std=legacy -march=native -mcmodel=medium -std=legacy -O0 -g -ffpe-trap=invalid,zero,overflow -DDEBUG -w -Itoolbox -DMPI -DUNDERSCORE -DGLOBAL_LONG_LONG -DTIMER -I/home/avmo/Sim_data/phill_run_12x10x8_V1.x1.x1._2021-10-12_23-21-58 -I/home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core -I./ -I /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/experimental /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/edgec.f -o obj/edgec.o
# mpif77 -c  -O2 -cpp -fdefault-real-8 -fdefault-double-8 -std=legacy -march=native -mcmodel=medium -std=legacy -O0 -g -ffpe-trap=invalid,zero,overflow -DDEBUG -w -Itoolbox -DMPI -DUNDERSCORE -DGLOBAL_LONG_LONG -DTIMER -I/home/avmo/Sim_data/phill_run_12x10x8_V1.x1.x1._2021-10-12_23-21-58 -I/home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core -I./ -I /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/experimental /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/eigsolv.f -o obj/eigsolv.o
# mpif77 -c  -O2 -cpp -fdefault-real-8 -fdefault-double-8 -std=legacy -march=native -mcmodel=medium -std=legacy -O0 -g -ffpe-trap=invalid,zero,overflow -DDEBUG -w -Itoolbox -DMPI -DUNDERSCORE -DGLOBAL_LONG_LONG -DTIMER -I/home/avmo/Sim_data/phill_run_12x10x8_V1.x1.x1._2021-10-12_23-21-58 -I/home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core -I./ -I /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/experimental /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/gauss.f -o obj/gauss.o
# mpif77 -c  -O2 -cpp -fdefault-real-8 -fdefault-double-8 -std=legacy -march=native -mcmodel=medium -std=legacy -O0 -g -ffpe-trap=invalid,zero,overflow -DDEBUG -w -Itoolbox -DMPI -DUNDERSCORE -DGLOBAL_LONG_LONG -DTIMER -I/home/avmo/Sim_data/phill_run_12x10x8_V1.x1.x1._2021-10-12_23-21-58 -I/home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core -I./ -I /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/experimental /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/genxyz.f -o obj/genxyz.o
# mpif77 -c  -O2 -cpp -fdefault-real-8 -fdefault-double-8 -std=legacy -march=native -mcmodel=medium -std=legacy -O0 -g -ffpe-trap=invalid,zero,overflow -DDEBUG -w -Itoolbox -DMPI -DUNDERSCORE -DGLOBAL_LONG_LONG -DTIMER -I/home/avmo/Sim_data/phill_run_12x10x8_V1.x1.x1._2021-10-12_23-21-58 -I/home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core -I./ -I /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/experimental /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/navier1.f -o obj/navier1.o
# mpif77 -c  -O2 -cpp -fdefault-real-8 -fdefault-double-8 -std=legacy -march=native -mcmodel=medium -std=legacy -O0 -g -ffpe-trap=invalid,zero,overflow -DDEBUG -w -Itoolbox -DMPI -DUNDERSCORE -DGLOBAL_LONG_LONG -DTIMER -I/home/avmo/Sim_data/phill_run_12x10x8_V1.x1.x1._2021-10-12_23-21-58 -I/home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core -I./ -I /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/experimental /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/makeq.f -o obj/makeq.o
# mpif77 -c  -O2 -cpp -fdefault-real-8 -fdefault-double-8 -std=legacy -march=native -mcmodel=medium -std=legacy -O0 -g -ffpe-trap=invalid,zero,overflow -DDEBUG -w -Itoolbox -DMPI -DUNDERSCORE -DGLOBAL_LONG_LONG -DTIMER -I/home/avmo/Sim_data/phill_run_12x10x8_V1.x1.x1._2021-10-12_23-21-58 -I/home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core -I./ -I /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/experimental /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/navier0.f -o obj/navier0.o
# mpif77 -c  -O2 -cpp -fdefault-real-8 -fdefault-double-8 -std=legacy -march=native -mcmodel=medium -std=legacy -O0 -g -ffpe-trap=invalid,zero,overflow -DDEBUG -w -Itoolbox -DMPI -DUNDERSCORE -DGLOBAL_LONG_LONG -DTIMER -I/home/avmo/Sim_data/phill_run_12x10x8_V1.x1.x1._2021-10-12_23-21-58 -I/home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core -I./ -I /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/experimental /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/navier2.f -o obj/navier2.o
# mpif77 -c  -O2 -cpp -fdefault-real-8 -fdefault-double-8 -std=legacy -march=native -mcmodel=medium -std=legacy -O0 -g -ffpe-trap=invalid,zero,overflow -DDEBUG -w -Itoolbox -DMPI -DUNDERSCORE -DGLOBAL_LONG_LONG -DTIMER -I/home/avmo/Sim_data/phill_run_12x10x8_V1.x1.x1._2021-10-12_23-21-58 -I/home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core -I./ -I /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/experimental /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/navier3.f -o obj/navier3.o
# mpif77 -c  -O2 -cpp -fdefault-real-8 -fdefault-double-8 -std=legacy -march=native -mcmodel=medium -std=legacy -O0 -g -ffpe-trap=invalid,zero,overflow -DDEBUG -w -Itoolbox -DMPI -DUNDERSCORE -DGLOBAL_LONG_LONG -DTIMER -I/home/avmo/Sim_data/phill_run_12x10x8_V1.x1.x1._2021-10-12_23-21-58 -I/home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core -I./ -I /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/experimental /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/navier4.f -o obj/navier4.o
# mpif77 -c  -O2 -cpp -fdefault-real-8 -fdefault-double-8 -std=legacy -march=native -mcmodel=medium -std=legacy -O0 -g -ffpe-trap=invalid,zero,overflow -DDEBUG -w -Itoolbox -DMPI -DUNDERSCORE -DGLOBAL_LONG_LONG -DTIMER -I/home/avmo/Sim_data/phill_run_12x10x8_V1.x1.x1._2021-10-12_23-21-58 -I/home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core -I./ -I /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/experimental /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/prepost.f -o obj/prepost.o
# mpif77 -c  -O2 -cpp -fdefault-real-8 -fdefault-double-8 -std=legacy -march=native -mcmodel=medium -std=legacy -O0 -g -ffpe-trap=invalid,zero,overflow -DDEBUG -w -Itoolbox -DMPI -DUNDERSCORE -DGLOBAL_LONG_LONG -DTIMER -I/home/avmo/Sim_data/phill_run_12x10x8_V1.x1.x1._2021-10-12_23-21-58 -I/home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core -I./ -I /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/experimental /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/speclib.f -o obj/speclib.o
# mpif77 -c  -O2 -cpp -fdefault-real-8 -fdefault-double-8 -std=legacy -march=native -mcmodel=medium -std=legacy -O0 -g -ffpe-trap=invalid,zero,overflow -DDEBUG -w -Itoolbox -DMPI -DUNDERSCORE -DGLOBAL_LONG_LONG -DTIMER -I/home/avmo/Sim_data/phill_run_12x10x8_V1.x1.x1._2021-10-12_23-21-58 -I/home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core -I./ -I /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/experimental /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/map2.f -o obj/map2.o
# mpif77 -c  -O2 -cpp -fdefault-real-8 -fdefault-double-8 -std=legacy -march=native -mcmodel=medium -std=legacy -O0 -g -ffpe-trap=invalid,zero,overflow -DDEBUG -w -Itoolbox -DMPI -DUNDERSCORE -DGLOBAL_LONG_LONG -DTIMER -I/home/avmo/Sim_data/phill_run_12x10x8_V1.x1.x1._2021-10-12_23-21-58 -I/home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core -I./ -I /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/experimental /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/mvmesh.f -o obj/mvmesh.o
# mpif77 -c  -O2 -cpp -fdefault-real-8 -fdefault-double-8 -std=legacy -march=native -mcmodel=medium -std=legacy -O0 -g -ffpe-trap=invalid,zero,overflow -DDEBUG -w -Itoolbox -DMPI -DUNDERSCORE -DGLOBAL_LONG_LONG -DTIMER -I/home/avmo/Sim_data/phill_run_12x10x8_V1.x1.x1._2021-10-12_23-21-58 -I/home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core -I./ -I /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/experimental /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/ic.f -o obj/ic.o
# mpif77 -c  -O2 -cpp -fdefault-real-8 -fdefault-double-8 -std=legacy -march=native -mcmodel=medium -std=legacy -O0 -g -ffpe-trap=invalid,zero,overflow -DDEBUG -w -Itoolbox -DMPI -DUNDERSCORE -DGLOBAL_LONG_LONG -DTIMER -I/home/avmo/Sim_data/phill_run_12x10x8_V1.x1.x1._2021-10-12_23-21-58 -I/home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core -I./ -I /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/experimental /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/gfldr.f -o obj/gfldr.o
# mpif77 -c  -O2 -cpp -fdefault-real-8 -fdefault-double-8 -std=legacy -march=native -mcmodel=medium -std=legacy -O0 -g -ffpe-trap=invalid,zero,overflow -DDEBUG -w -Itoolbox -DMPI -DUNDERSCORE -DGLOBAL_LONG_LONG -DTIMER -I/home/avmo/Sim_data/phill_run_12x10x8_V1.x1.x1._2021-10-12_23-21-58 -I/home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core -I./ -I /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/experimental /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/ssolv.f -o obj/ssolv.o
# mpif77 -c  -O2 -cpp -fdefault-real-8 -fdefault-double-8 -std=legacy -march=native -mcmodel=medium -std=legacy -O0 -g -ffpe-trap=invalid,zero,overflow -DDEBUG -w -Itoolbox -DMPI -DUNDERSCORE -DGLOBAL_LONG_LONG -DTIMER -I/home/avmo/Sim_data/phill_run_12x10x8_V1.x1.x1._2021-10-12_23-21-58 -I/home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core -I./ -I /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/experimental /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/planx.f -o obj/planx.o
# mpif77 -c  -O3 -cpp -fdefault-real-8 -fdefault-double-8 -std=legacy -march=native -mcmodel=medium -std=legacy -O0 -g -ffpe-trap=invalid,zero,overflow -DDEBUG -w -Itoolbox -DMPI -DUNDERSCORE -DGLOBAL_LONG_LONG -DTIMER -I/home/avmo/Sim_data/phill_run_12x10x8_V1.x1.x1._2021-10-12_23-21-58 -I/home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core -I./ -I /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/experimental /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/math.f -o obj/math.o
# mpif77 -c  -O2 -cpp -fdefault-real-8 -fdefault-double-8 -std=legacy -march=native -mcmodel=medium -std=legacy -O0 -g -ffpe-trap=invalid,zero,overflow -DDEBUG -w -Itoolbox -DMPI -DUNDERSCORE -DGLOBAL_LONG_LONG -DTIMER -I/home/avmo/Sim_data/phill_run_12x10x8_V1.x1.x1._2021-10-12_23-21-58 -I/home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core -I./ -I /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/experimental /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/mxm_wrapper.f -o obj/mxm_wrapper.o
# mpif77 -c  -O2 -cpp -fdefault-real-8 -fdefault-double-8 -std=legacy -march=native -mcmodel=medium -std=legacy -O0 -g -ffpe-trap=invalid,zero,overflow -DDEBUG -w -Itoolbox -DMPI -DUNDERSCORE -DGLOBAL_LONG_LONG -DTIMER -I/home/avmo/Sim_data/phill_run_12x10x8_V1.x1.x1._2021-10-12_23-21-58 -I/home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core -I./ -I /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/experimental /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/hmholtz.f -o obj/hmholtz.o
# mpif77 -c  -O2 -cpp -fdefault-real-8 -fdefault-double-8 -std=legacy -march=native -mcmodel=medium -std=legacy -O0 -g -ffpe-trap=invalid,zero,overflow -DDEBUG -w -Itoolbox -DMPI -DUNDERSCORE -DGLOBAL_LONG_LONG -DTIMER -I/home/avmo/Sim_data/phill_run_12x10x8_V1.x1.x1._2021-10-12_23-21-58 -I/home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core -I./ -I /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/experimental /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/subs1.f -o obj/subs1.o
# mpif77 -c  -O2 -cpp -fdefault-real-8 -fdefault-double-8 -std=legacy -march=native -mcmodel=medium -std=legacy -O0 -g -ffpe-trap=invalid,zero,overflow -DDEBUG -w -Itoolbox -DMPI -DUNDERSCORE -DGLOBAL_LONG_LONG -DTIMER -I/home/avmo/Sim_data/phill_run_12x10x8_V1.x1.x1._2021-10-12_23-21-58 -I/home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core -I./ -I /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/experimental /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/subs2.f -o obj/subs2.o
# mpif77 -c  -O2 -cpp -fdefault-real-8 -fdefault-double-8 -std=legacy -march=native -mcmodel=medium -std=legacy -O0 -g -ffpe-trap=invalid,zero,overflow -DDEBUG -w -Itoolbox -DMPI -DUNDERSCORE -DGLOBAL_LONG_LONG -DTIMER -I/home/avmo/Sim_data/phill_run_12x10x8_V1.x1.x1._2021-10-12_23-21-58 -I/home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core -I./ -I /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/experimental /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/gmres.f -o obj/gmres.o
# mpif77 -c  -O2 -cpp -fdefault-real-8 -fdefault-double-8 -std=legacy -march=native -mcmodel=medium -std=legacy -O0 -g -ffpe-trap=invalid,zero,overflow -DDEBUG -w -Itoolbox -DMPI -DUNDERSCORE -DGLOBAL_LONG_LONG -DTIMER -I/home/avmo/Sim_data/phill_run_12x10x8_V1.x1.x1._2021-10-12_23-21-58 -I/home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core -I./ -I /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/experimental /home/avmo/src/snek5000/snek5000/src/snek5000/../../lib/Nek5000/core/hsmg.f -o obj/hsmg.o
# ...
#           2  U-PRES gmres     120   1.0242E-06   3.8450E+00   1.0000E-08   9.5971E-01   2.4473E+00
#           2  Hmholtz VELX       4   2.2799E-09   9.9974E-01   1.0000E-08
#           0  U-PRES gmres       5   8.9760E-05   6.2439E-04   1.0000E-04   4.5787E-02   1.0296E-01
#           2  Volflow X              4.0000E-04   5.8342E+02   9.4805E-01   8.2095E+00   9.1575E+00
#           2  Fluid done  4.0000E-04  2.8179E+00
# Step      3, t= 6.0000000E-04, DT= 2.0000000E-04, C=  0.006 7.1668E+00 2.9134E+00
#              Solving for fluid
#           3  Hmholtz VELX       6   4.3450E-10   3.9666E+02   1.0000E-08
#           3  Hmholtz VELY       6   3.3317E-10   3.6018E+02   1.0000E-08
#           3  Hmholtz VELZ       5   3.9846E-10   3.5205E+00   1.0000E-08
#           3  U-PRES gmres     120   1.3519E-06   1.1598E+00   1.0000E-08   9.0817E-01   2.3960E+00
#           3  Volflow X              6.0000E-04   1.1625E+01   1.8890E-02   9.1386E+00   9.1575E+00
#           3  Fluid done  6.0000E-04  2.5711E+00
#   [STAT] Average compute
# Step      4, t= 8.0000000E-04, DT= 2.0000000E-04, C=  0.005 9.9148E+00 2.7480E+00
#              Solving for fluid
#           4  Hmholtz VELX       6   1.5284E-10   5.3362E+01   1.0000E-08
#           4  Hmholtz VELY       5   6.5974E-09   4.3226E+01   1.0000E-08
#           4  Hmholtz VELZ       5   1.9783E-10   2.2562E+00   1.0000E-08
#           4  U-PRES gmres     120   6.6707E-07   1.1887E-01   1.0000E-08   8.8634E-01   2.3568E+00
#           4  Volflow X              8.0000E-04  -1.4793E+00  -2.4038E-03   9.1599E+00   9.1575E+00
#           4  Fluid done  8.0000E-04  2.5320E+00
# Step      5, t= 1.0000000E-03, DT= 2.0000000E-04, C=  0.005 1.2521E+01 2.6065E+00
#              Solving for fluid
#           5  Hmholtz VELX       5   6.6950E-09   1.1910E+01   1.0000E-08
#           5  Hmholtz VELY       5   2.3285E-09   6.5344E+00   1.0000E-08
#           5  Hmholtz VELZ       4   3.0959E-09   3.6440E-01   1.0000E-08
#           5  U-PRES gmres     120   1.8227E-07   1.3956E-02   1.0000E-08   9.2423E-01   2.4312E+00
#           5  Volflow X              1.0000E-03   2.9044E-01   4.7196E-04   9.1570E+00   9.1575E+00
#           5  Fluid done  1.0000E-03  2.6113E+00
# Step      6, t= 1.2000000E-03, DT= 2.0000000E-04, C=  0.005 1.5208E+01 2.6867E+00
#              Solving for fluid
#           6  Project VELX           1.8163E+00   9.5020E-01   5.2315E-01   1   8
#           6  Hmholtz VELX       5   2.0665E-09   5.1345E+00   1.0000E-08
#           6  Project VELY           6.9966E-01   3.2958E-01   4.7106E-01   1   8
#           6  Hmholtz VELY       5   1.3226E-09   2.5616E+00   1.0000E-08
#           6  Project VELZ           2.7264E-02   2.9689E-02   1.0890E+00   1   8
#           6  Hmholtz VELZ       4   7.1873E-10   5.2620E-02   1.0000E-08
#           6  Project PRES           4.1665E+00   6.4248E+00   1.5420E+00   1  20
#           6  U-PRES gmres     120   9.3411E-08   5.5553E-04   1.0000E-08   8.9852E-01   2.3812E+00
#           6  Volflow X              1.2000E-03   3.4493E-01   5.6050E-04   9.1569E+00   9.1575E+00
#           6  Fluid done  1.2000E-03  2.5938E+00
#   [STAT] Average compute
# Step      7, t= 1.4000000E-03, DT= 2.0000000E-04, C=  0.005 1.7980E+01 2.7722E+00
#              Solving for fluid
#           7  Project VELX           4.0978E-02   8.9025E-01   2.1725E+01   2   8
#           7  Hmholtz VELX       4   9.6145E-09   3.0850E-01   1.0000E-08
#           7  Project VELY           1.7763E-02   3.2058E-01   1.8048E+01   2   8
#           7  Hmholtz VELY       4   5.0150E-09   1.1930E-01   1.0000E-08
#           7  Project VELZ           7.6494E-04   2.7373E-02   3.5785E+01   2   8
#           7  Hmholtz VELZ       3   3.6896E-09   1.6524E-03   1.0000E-08
#           7  Project PRES           2.3331E+00   2.9989E+00   1.2853E+00   2  20
#           7  U-PRES gmres     120   4.6299E-08   3.1109E-04   1.0000E-08   8.7733E-01   2.3512E+00
#           7  Volflow X              1.4000E-03   3.2548E-01   5.2890E-04   9.1570E+00   9.1575E+00
#           7  Fluid done  1.4000E-03  2.5445E+00
# Step      8, t= 1.6000000E-03, DT= 2.0000000E-04, C=  0.005 2.0601E+01 2.6203E+00
#              Solving for fluid
#           8  Project VELX           4.6386E-03   8.3103E-01   1.7916E+02   3   8
#           8  Hmholtz VELX       4   5.7009E-10   1.5396E-02   1.0000E-08
#           8  Project VELY           1.5983E-03   2.9310E-01   1.8338E+02   3   8
#           8  Hmholtz VELY       4   3.2374E-10   7.5649E-03   1.0000E-08
#           8  Project VELZ           2.7320E-04   2.5992E-02   9.5139E+01   3   8
#           8  Hmholtz VELZ       3   7.7024E-10   5.4620E-04   1.0000E-08
#           8  Project PRES           1.8007E-01   2.7977E+00   1.5537E+01   3  20
#           8  U-PRES gmres      25   8.8773E-09   2.4009E-05   1.0000E-08   2.0794E-01   4.9928E-01
#           8  Volflow X              1.6000E-03   3.1208E-01   5.0712E-04   9.1570E+00   9.1575E+00
#           8  Fluid done  1.6000E-03  7.0421E-01
#   [MSTEP] Writing checkpoint snapshot
#   [IOTOOL] Opening file: rs6phill0.f00001
#  min/max:   0.0000       9.0000     -0.63238E-18   3.0350       0.0000       4.5000
#  min/max:   0.0000       1.5107     -0.71916      0.71932     -0.19394E-02  0.17830E-02
#  min/max:  -1.7314      0.98855
#   [MSTEP] Checkpoint written:
# Step      9, t= 1.8000000E-03, DT= 2.0000000E-04, C=  0.005 2.1441E+01 8.4090E-01
#              Solving for fluid
#           9  Project VELX           2.2488E-03   7.7920E-01   3.4650E+02   4   8
#           9  Hmholtz VELX       4   2.5330E-10   7.7468E-03   1.0000E-08
#           9  Project VELY           5.4181E-04   2.7157E-01   5.0123E+02   4   8
#           9  Hmholtz VELY       4   1.1506E-10   3.0341E-03   1.0000E-08
#           9  Project VELZ           1.6188E-04   2.4689E-02   1.5251E+02   4   8
#           9  Hmholtz VELZ       3   3.1893E-10   3.2335E-04   1.0000E-08
#           9  Project PRES           1.3124E-01   2.5939E+00   1.9765E+01   4  20
#           9  U-PRES gmres      24   7.4004E-09   1.7499E-05   1.0000E-08   4.0888E-01   8.7024E-01
#           9  Volflow X              1.8000E-03   3.0007E-01   4.8761E-04   9.1570E+00   9.1575E+00
#           9  Fluid done  1.8000E-03  1.2413E+00
#   [IOTOOL] Opening file: rs6phill0.f00002
#  min/max:   0.0000       1.5076     -0.71557      0.71594     -0.19150E-02  0.17464E-02
#  min/max:  -1.6965      0.94660
#   [MSTEP] Checkpoint written:
#   [STAT] Average compute
# Step     10, t= 2.0000000E-03, DT= 2.0000000E-04, C=  0.005 2.2951E+01 1.5098E+00
#              Solving for fluid
#          10  Project VELX           5.2224E-04   7.3327E-01   1.4041E+03   5   8
#          10  Hmholtz VELX       3   3.8042E-09   1.3891E-03   1.0000E-08
#          10  Project VELY           3.7372E-04   2.5333E-01   6.7785E+02   5   8
#          10  Hmholtz VELY       3   1.1234E-09   8.3305E-04   1.0000E-08
#          10  Project VELZ           3.4781E-05   2.3467E-02   6.7471E+02   5   8
#          10  Hmholtz VELZ       3   3.0151E-10   9.7044E-05   1.0000E-08
#          10  Project PRES           6.6282E-02   2.4125E+00   3.6398E+01   5  20
#          10  U-PRES gmres      15   8.7578E-09   8.8376E-06   1.0000E-08   2.2632E-01   5.0835E-01
#          10  Volflow X              2.0000E-03   2.8901E-01   4.6963E-04   9.1570E+00   9.1575E+00
#          10  Fluid done  2.0000E-03  8.3270E-01
#   [IOTOOL] Opening file: rs6phill0.f00003
#  min/max:   0.0000       1.5036     -0.71141      0.71204     -0.18912E-02  0.17111E-02
#  min/max:  -1.6641      0.90865
#   [MSTEP] Checkpoint written:
#   [MSTEP] Written checkpoint snapshot number:  1
#   [STAT] Global sum
# gs_setup: 4320 unique labels shared
#    pairwise times (avg, min, max): 1.00023e-05 6.8125e-06 1.50228e-05
#    crystal router                : 2.78633e-05 2.72417e-05 2.86867e-05
#    all reduce                    : 0.000103376 0.000102464 0.000104718
#    used all_to_all method: pairwise
#    handle bytes (avg, min, max): 34844 34844 34844
#    buffer bytes (avg, min, max): 34560 34560 34560
#   [STAT] Writing stat file
#        FILE:/home/avmo/Sim_data/phill_run_12x10x8_V1.x1.x1._2021-10-12_23-21-58/c2Dphill0.f00001
#        FILE:/home/avmo/Sim_data/phill_run_12x10x8_V1.x1.x1._2021-10-12_23-21-58/stsphill0.f00001
#  min/max: -0.63238E-18   9.0000
#  min/max:   0.0000       1.5066
#  min/max: -0.72027      0.72021
#  min/max: -0.41005E-03  0.33868E-03
#  min/max:  -66.567       67.286
#  min/max:   0.0000       2.2699
#  min/max:   0.0000      0.51880
#  min/max:   0.0000      0.51137E-06
#  min/max:  0.14265E-02   13372.
#  min/max: -0.78974      0.78931
#  min/max: -0.14088E-03  0.13259E-03
#  min/max: -0.38240E-03  0.34555E-03
#  min/max:  -35.744       36.016
#  min/max: -0.10584       28.185
#  min/max: -0.16081E-01  0.14595E-01
#  min/max:  -15722.       464.73
#  min/max:  -22585.       22131.
#  min/max: -0.88337E-03  0.84421E-03
#  min/max:  -12709.       12608.
#  min/max:  -440.95       16203.
#  min/max: -0.57169E-03  0.89980E-03
#  min/max:  -8.8059       5.7926
#  min/max:  -11.227       8.9348
#  min/max: -0.82339E-03  0.89370E-03
#  min/max:   0.0000       3.4200
#  min/max: -0.37370      0.37360
#  min/max: -0.25020E-09  0.25998E-09
#  min/max: -0.86595      0.86507
#  min/max: -0.51176E-03  0.48607E-03
#  min/max:   0.0000      0.56886
#  min/max: -0.41111E-04  0.81737E-04
#  min/max:   0.0000      0.60166E-06
#  min/max: -0.23656E-06  0.25001E-06
#  min/max: -0.26145E+07  0.26783E+07
#  min/max:  0.30302E-05  0.53646E+09
#  min/max: -0.11787E-03  0.14043E-03
#  min/max:   0.0000       5.1528
#  min/max:   0.0000      0.26918
#  min/max:   0.0000      0.42619E-12
#  min/max:  0.16720E-03  0.85426E+06
#  min/max:  0.13198E-03  0.22064E+06
#  min/max:  0.50843E-04  0.30949
#  min/max: -0.32122E+06  0.32553E+06
#  min/max:  -139.34       119.97
#  min/max:  -81.357       85.356
#
#        10  2.0000E-03 done :: Write checkpoint
#                               file size =      1.5    MB
#                               avg data-throughput =    84.5MB/s
#                               io-nodes =    12
#
#   [MONITOR] Summary of registered timers
#
# Module name        Timer name :          Count       Min time       Max time      Max/count
# [FRAME     ]  FRM_TOT         : 0.10000000E+01 0.24086048E+02 0.24091990E+02 0.24091990E+02
# [CHKPOINT  ]    CHP_TOT       : 0.50000000E+01 0.40485861E-01 0.41511718E-01 0.83023436E-02
# [CHKPOINT  ]      CHP_INI     : 0.20000000E+01 0.18274530E-02 0.19872360E-02 0.99361800E-03
# [MSTEP     ]      CHP_READ    : 0.00000000E+00 0.00000000E+00 0.00000000E+00 0.00000000E+00
# [MSTEP     ]      CHP_WRITE   : 0.30000000E+01 0.38539122E-01 0.39524482E-01 0.13174827E-01
# [MAP2D     ]    MAP2D_TOT     : 0.30000000E+01 0.19304246E-01 0.31606996E-01 0.10535665E-01
# [STAT      ]    STAT_TOT      : 0.70000000E+01 0.32964763E+00 0.35172072E+00 0.50245817E-01
# [STAT      ]      STAT_INI    : 0.10000000E+01 0.16276082E-01 0.22561778E-01 0.22561778E-01
# [STAT      ]      STAT_AVG    : 0.30000000E+01 0.28026993E+00 0.29829027E+00 0.99430091E-01
# [STAT      ]      STAT_CMM    : 0.10000000E+01 0.92464800E-02 0.10066123E-01 0.10066123E-01
# [STAT      ]      STAT_IO     : 0.10000000E+01 0.18246465E-01 0.26872749E-01 0.26872749E-01
#
#
#        10  2.0000E-03 Write checkpoint
#        FILE:/home/avmo/Sim_data/phill_run_12x10x8_V1.x1.x1._2021-10-12_23-21-58/phill0.f00001
#  min/max:   0.0000       9.0000     -0.63238E-18   3.0350       0.0000       4.5000
#  min/max:   0.0000       1.5036     -0.71141      0.71204     -0.18912E-02  0.17111E-02
#  min/max:  -1.6516      0.90818
#
#        10  2.0000E-03 done :: Write checkpoint
#                               file size =      11.    MB
#                               avg data-throughput =   512.5MB/s
#                               io-nodes =    12
#
#
# end of time-step loop
#
#
# runtime statistics:
#  init time   1.3318733610000000        5.5486064989566881E-002
#  prep time           1   2.3769243999996803E-002   9.9023064501152307E-004
#  pres time          10   19.991726638000003       0.83285864555235556
#  crsl time         918  0.50823065800001999        2.1172973456204929E-002
#  crsl min   0.43587163100005100
#  crsl max   0.53086550000006127
#  crsl avg   0.48048593999999856
#  hmhz time          18   1.4312751839999991        5.9627161412516790E-002
#  eslv time          12   19.979136065000002       0.83233412019417186
#  makf time  0.47191798700000209        1.9660181563183689E-002
#  makq time   0.0000000000000000        0.0000000000000000
#  proj time  0.30973817199999587        1.2903743587481675E-002
#  usvp time          12   2.7311119999970934E-003   1.1377857862690948E-004
#  usfq time           0   2.5212269000002285E-002   1.0503473057064689E-003
#  usbc time          10   5.7173147999996399E-002   2.3818428226570153E-003
#  usbc min    5.0706606999999737E-002
#  usbc max    7.1008638000002344E-002
#  usb  avg    6.2722509416666947E-002
#  uchk time  0.38169702400000460        1.5901561289646159E-002
#  mltd time        2886   3.5856477180000845       0.14937867828609935
#  cdtp time        2916   4.1829570829999891       0.17426268544153764
#  axhm time         296  0.94545769199997953        3.9387924167061085E-002
#  advc time          30  0.36624173599999987        1.5257691429709275E-002
#  mxmf time   0.0000000000000000        0.0000000000000000
#  adc3 time   0.0000000000000000        0.0000000000000000
#  col2 time   0.0000000000000000        0.0000000000000000
#  col3 time   0.0000000000000000        0.0000000000000000
#  a2s2 time   0.0000000000000000        0.0000000000000000
#  add2 time   0.0000000000000000        0.0000000000000000
#  invc time   0.0000000000000000        0.0000000000000000
#  tgop time        3952   1.9911151030001366        8.2950185236698143E-002
#  dadd time           0  0.95058585100004578        3.9601564121043549E-002
#  vdss time         963  0.76534455099998988        3.1884380857585395E-002
#  vdss min   0.76534455099998988
#  vdss max    1.3052244959999595
#  vdss avg    1.0895480090833358
#  dsum time        3087   1.3307991259999776        5.5441312181401581E-002
#  dsum min    1.3262936619999690
#  dsum max    1.5931403469998955
#  dsum avg    1.4562071703332891
#  ddsl time         918   7.8708833439999752       0.32790230478262572
#
#
# #  nid       tusbc       tdadd       tcrsl       tvdss       tdsum        tgop    qqq    F
#            0  5.7173E-02  9.5059E-01  5.0823E-01  7.6534E-01  1.3308E+00  1.9911E+00 qqq
#            1  6.6094E-02  1.0557E+00  5.3087E-01  1.0228E+00  1.4823E+00  1.9038E+00 qqq
#            2  6.7607E-02  1.0324E+00  5.2470E-01  1.0205E+00  1.3726E+00  2.0571E+00 qqq
#            3  6.9916E-02  1.0262E+00  4.3842E-01  1.2270E+00  1.5310E+00  1.6802E+00 qqq
#            4  6.8792E-02  1.0125E+00  4.3714E-01  1.3052E+00  1.4131E+00  1.6415E+00 qqq
#            5  6.8632E-02  1.0589E+00  4.4282E-01  1.2653E+00  1.5308E+00  1.7124E+00 qqq
#            6  5.3039E-02  1.0090E+00  4.3901E-01  1.0473E+00  1.5931E+00  1.6850E+00 qqq
#            7  6.7124E-02  1.0324E+00  4.4753E-01  1.2417E+00  1.5303E+00  1.5756E+00 qqq
#            8  5.5932E-02  1.0334E+00  4.3587E-01  1.1177E+00  1.5665E+00  1.6529E+00 qqq
#            9  5.6646E-02  1.0850E+00  5.1788E-01  9.8627E-01  1.3925E+00  2.0373E+00 qqq
#           10  7.1009E-02  1.1181E+00  5.2326E-01  1.0948E+00  1.3263E+00  1.9282E+00 qqq
#           11  5.0707E-02  1.1405E+00  5.2010E-01  9.8050E-01  1.4052E+00  2.0186E+00 qqq
#
# run successful: dying ...
#
#
# total elapsed time             :   2.54155E+01 sec
# total solver time w/o IO       :   2.39800E+01 sec
# time/timestep                  :   2.39800E+00 sec
# avg throughput per timestep    :   4.25355E+03 gridpts/CPUs
# total max memory usage         :   1.03411E+00 GB
# [Tue Oct 12 23:22:30 2021]
# Finished job 0.
# 7 of 7 steps (100%) done
# Complete log: /home/avmo/src/snek5000/snek5000/lib/Nek5000/.snakemake/log/2021-10-12T232158.804271.snakemake.log
# True

# %%
# !ls {sim.path_run}
# Out:
# build.log	       map2d_loc.txt002i001  map2d_usr.txt011i001
# c2Dphill0.f00001       map2d_loc.txt003i001  nek5000
# etc		       map2d_loc.txt004i001  obj
# info_solver.xml        map2d_loc.txt005i001  params_simul.xml
# logs		       map2d_loc.txt006i001  phill0.f00001
# makefile	       map2d_loc.txt007i001  phill.box
# makefile_usr.inc       map2d_loc.txt008i001  phill.f
# map2d_glob.txt000i001  map2d_loc.txt009i001  phill.log
# map2d_glob.txt001i001  map2d_loc.txt010i001  phill.ma2
# map2d_glob.txt002i001  map2d_loc.txt011i001  phill.par
# map2d_glob.txt003i001  map2d_usr.txt000i001  phill.re2
# map2d_glob.txt004i001  map2d_usr.txt001i001  phill.usr
# map2d_glob.txt005i001  map2d_usr.txt002i001  rs6phill0.f00001
# map2d_glob.txt006i001  map2d_usr.txt003i001  rs6phill0.f00002
# map2d_glob.txt007i001  map2d_usr.txt004i001  rs6phill0.f00003
# map2d_glob.txt008i001  map2d_usr.txt005i001  SESSION.NAME
# map2d_glob.txt009i001  map2d_usr.txt006i001  SIZE
# map2d_glob.txt010i001  map2d_usr.txt007i001  Snakefile
# map2d_glob.txt011i001  map2d_usr.txt008i001  stsphill0.f00001
# map2d_loc.txt000i001   map2d_usr.txt009i001  templates
# map2d_loc.txt001i001   map2d_usr.txt010i001  toolbox

# %% [markdown]
# The simulation is done!
#
# ## Versions used in this tutorial

# %%
import snakemake
snakemake.__version__
# Out:
# '6.8.1'

# %%
import snek5000
snek5000.__version__
# Out:
# '0.7.0b1.dev4+ga2a7e55.d20210927'

# %%
import phill
phill.__version__
# Out:
# '0.3.0a1.dev23+gb47349c'
